# %% [markdown]
# <a href="https://colab.research.google.com/github/Shubhu1111/Retail-Sales-Prediction-Regression/blob/main/Retail_Sales_Prediction_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name    - Retail Sales Prediction**

# %% [markdown]
# ##### **Project Type**    - Regression
# ##### **Contribution**    - Individual
# ##### **Name**            - Shubham Singh

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# ####**Introduction**
#
# This sales prediction project, led by Shubham Singh, aims to accurately forecast sales for Rossmann. It utilizes the Rossmann dataset and the store dataset, employing regression techniques such as linear regression, LARS regression lasso, and decision tree. The project incorporates cross-validation through GridSearchCV and hyperparameter tuning to enhance model performance. By leveraging these models and techniques, the project aims to provide precise sales predictions, enabling Rossmann to make informed business decisions and optimize their operations.

# %% [markdown]
# ### **Data Description**
#
# The dataset includes two files:
#
# - **Rossmann Stores Data.csv**: This file contains historical sales data, including the target variable, "Sales".
# - **store.csv**: This file provides supplemental information about the stores.
#
# The following are descriptions for the fields in the dataset:
#
# - **Id**: A unique identifier that represents a (Store, Date) tuple within the test set.
# - **Store**: A unique identifier for each store.
# - **Sales**: The turnover for any given day (this is the target variable to be predicted).
# - **Customers**: The number of customers on a given day.
# - **Open**: An indicator for whether the store was open: 0 = closed, 1 = open.
# - **StateHoliday**: Indicates a state holiday. Normally all stores, with few exceptions, are closed on state holidays. Note that all schools are closed on public holidays and weekends. a = public holiday, b = Easter holiday, c = Christmas, 0 = None.
# - **SchoolHoliday**: Indicates if the (Store, Date) was affected by the closure of public schools.
# - **StoreType**: Differentiates between 4 different store models: a, b, c, d.
# - **Assortment**: Describes an assortment level: a = basic, b = extra, c = extended.
# - **CompetitionDistance**: Distance in meters to the nearest competitor store.
# - **CompetitionOpenSince[Month/Year]**: Gives the approximate year and month of the time the nearest competitor was opened.
# - **Promo**: Indicates whether a store is running a promo on that day.
# - **Promo2**: Promo2 is a continuing and consecutive promotion for some stores: 0 = store is not participating, 1 = store is participating.
# - **Promo2Since[Year/Week]**: Describes the year and calendar week when the store started participating in Promo2.
# - **PromoInterval**: Describes the consecutive intervals Promo2 is started, naming the months the promotion is started anew. For example, "Feb,May,Aug,Nov" means each round starts in February, May, August, November of any given year for that store.

# %% [markdown]
# ## **Data Wrangling**
# ### **Cleaning Data**
#
# Cleaning data is a crucial step before performing EDA, as it removes ambiguous data that can affect the outcome of EDA.
#
# While cleaning the data, we will perform the following steps:
#
# 1. Remove duplicate rows.
# 2. Handle missing values.
# 3. Convert columns to appropriate datatypes.
# 4. Add important columns.
#
# ## **Important Libraries**
#
# In this exploratory analysis, several libraries have been used, including but not limited to:
#
# - NumPy
# - Pandas
# - Matplotlib
# - Seaborn
# - Scikit-learn
# - Plotly
#
# ## **Machine Learning Models and Techniques**
# Linear Regression
#
# LARS Regression(Lasso)
#
# Decision Tree
#
# Cross Validation: GridSearchCV
#
# Hyper parameter tunning

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/Shubhu1111/Retail-Sales-Prediction-Regression

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# **Rossmann is a leading drugstore chain with over 3,000 stores operating across 7 European countries. Store managers are currently responsible for predicting their daily sales up to six weeks in advance, which can be challenging due to various factors that affect sales, such as promotions, competition, holidays, seasonality, and location. The accuracy of sales predictions can vary widely across managers.**
#
# **For this project, historical sales data is available for 1,115 Rossmann stores. The goal is to forecast the "Sales" column for the test set, while taking into account that some stores may have been temporarily closed for refurbishment.**
#
# **The dataset includes several fields, such as:**
#
# - **Id: a unique identifier that represents a (Store, Date) combination within the dataset.**
# - **Store: a unique identifier for each Rossmann store.**
# - **Sales: the turnover for a given day (this is the dependent variable to be predicted).**
# - **Customers: the number of customers on a given day.**
#
# **In summary, this project involves building a model to accurately predict sales for Rossmann stores based on historical sales data, store information, and other relevant factors. The aim is to provide more accurate sales predictions for store managers and help Rossmann make data-driven decisions to improve business outcomes.**

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 15 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]
#
#
#
#
#
# 6. You may add more ml algorithms for model creation. Make sure for each and every algorithm, the following format should be answered.
#
#
# *   Explain the ML Model used and it's performance using Evaluation metric Score Chart.
#
#
# *   Cross- Validation & Hyperparameter Tuning
#
# *   Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.
#
# *   Explain each evaluation metric's indication towards business and the business impact pf the ML model used.

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# !pip install numpy
# !pip install pandas
# !pip install matplotlib
# !pip install seaborn
# !pip install plotly
# !pip install missingno
# !pip install scipy
# !pip install statsmodels
# !pip install scikit-learn
# !pip install xgboost

# %%
# Data Manipulation and Analysis:
import numpy as np
import pandas as pd
import ast
import math
import random

# Data Visualization:
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import plotly.express as px
import missingno as msno

# Feature Engineering:
import scipy.stats as stats
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.preprocessing import OneHotEncoder

# Data Preprocessing:
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

# Model selection and evaluation:
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import KFold
from sklearn.model_selection import RandomizedSearchCV
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
from sklearn.linear_model import LassoLars
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error , make_scorer

# other:
from google.colab import drive
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# these codes are for Jupyter Notebook.

# %%
# import pandas as pd

# # read the CSV file with low_memory=False
# df_rossmann = pd.read_csv('C:/Rossmann Stores Data.csv', low_memory=False)
# df_rossmann.head()

# %%
# import pandas as pd

# # read the CSV file with low_memory=False
# df_store = pd.read_csv('C:/store.csv', low_memory=False)
# df_store.head()

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
# Store.csv
drive.mount('/content/drive')
path = '/content/drive/MyDrive/Data/store.csv'
df_store = pd.read_csv(path)
# Out:
# Mounted at /content/drive

# %%
# Load Dataset
# Rossmann Stores Data.csv
path1 = '/content/drive/MyDrive/Data/Rossmann Stores Data.csv'
df_rossmann = pd.read_csv(path1)

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
df_store.head()
# Out:
#    Store StoreType Assortment  CompetitionDistance  CompetitionOpenSinceMonth  \
# 0      1         c          a               1270.0                        9.0
# 1      2         a          a                570.0                       11.0
# 2      3         a          a              14130.0                       12.0
# 3      4         c          c                620.0                        9.0
# 4      5         a          a              29910.0                        4.0
#
#    CompetitionOpenSinceYear  Promo2  Promo2SinceWeek  Promo2SinceYear  \
# 0                    2008.0       0              NaN              NaN
# 1                    2007.0       1             13.0           2010.0
# 2                    2006.0       1             14.0           2011.0
# 3                    2009.0       0              NaN              NaN
# 4                    2015.0       0              NaN              NaN
#
#      PromoInterval
# 0              NaN
# 1  Jan,Apr,Jul,Oct
# ...

# %%
df_rossmann.head()
# Out:
#    Store  DayOfWeek        Date  Sales  Customers  Open  Promo StateHoliday  \
# 0      1          5  2015-07-31   5263        555     1      1            0
# 1      2          5  2015-07-31   6064        625     1      1            0
# 2      3          5  2015-07-31   8314        821     1      1            0
# 3      4          5  2015-07-31  13995       1498     1      1            0
# 4      5          5  2015-07-31   4822        559     1      1            0
#
#    SchoolHoliday
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
print(f'there are {df_store.shape[0]} rows and {df_store.shape[1]} columns')
# Out:
# there are 1115 rows and 10 columns

# %%
print(f'there are {df_rossmann.shape[0]} rows and {df_rossmann.shape[1]} columns')
# Out:
# there are 1017209 rows and 9 columns

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df_store.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1115 entries, 0 to 1114
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Store                      1115 non-null   int64
#  1   StoreType                  1115 non-null   object
#  2   Assortment                 1115 non-null   object
#  3   CompetitionDistance        1112 non-null   float64
#  4   CompetitionOpenSinceMonth  761 non-null    float64
#  5   CompetitionOpenSinceYear   761 non-null    float64
#  6   Promo2                     1115 non-null   int64
#  7   Promo2SinceWeek            571 non-null    float64
#  8   Promo2SinceYear            571 non-null    float64
#  9   PromoInterval              571 non-null    object
# dtypes: float64(5), int64(2), object(3)
# memory usage: 87.2+ KB

# %%
# Dataset Info
df_rossmann.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1017209 entries, 0 to 1017208
# Data columns (total 9 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   Store          1017209 non-null  int64
#  1   DayOfWeek      1017209 non-null  int64
#  2   Date           1017209 non-null  object
#  3   Sales          1017209 non-null  int64
#  4   Customers      1017209 non-null  int64
#  5   Open           1017209 non-null  int64
#  6   Promo          1017209 non-null  int64
#  7   StateHoliday   1017209 non-null  object
#  8   SchoolHoliday  1017209 non-null  int64
# dtypes: int64(7), object(2)
# memory usage: 69.8+ MB

# %% [markdown]
# ### **Rename these two dataframe**

# %%
# Rename df_store to store
store = df_store
#  Rename df_rossmann to sales
sales = df_rossmann

# %% [markdown]
# ### **Let's check how many years of data we have.**

# %%
print('Start data point',sales['Date'].min())
print('End data point',sales['Date'].max())
# Out:
# Start data point 2013-01-01
# End data point 2015-07-31

# %% [markdown]
# *This indicates that we have nearly three years of data.*

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
store.duplicated().sum()
# Out:
# 0

# %%
sales.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
store.isna().sum()
# Out:
# Store                          0
# StoreType                      0
# Assortment                     0
# CompetitionDistance            3
# CompetitionOpenSinceMonth    354
# CompetitionOpenSinceYear     354
# Promo2                         0
# Promo2SinceWeek              544
# Promo2SinceYear              544
# PromoInterval                544
# dtype: int64

# %%
print(f'The store dataset has {store.isna().sum().sum()} values that are either missing or null.')
# Out:
# The store dataset has 2343 values that are either missing or null.

# %%
# Visualizing the missing values
msno.matrix(store)  #1
# Out:
# <Axes: >

# %%
# Visualizing the missing values
msno.bar(store)  #2
# Out:
# <Axes: >

# %%
# Missing Values/Null Values Count
sales.isnull().sum()
# Out:
# Store            0
# DayOfWeek        0
# Date             0
# Sales            0
# Customers        0
# Open             0
# Promo            0
# StateHoliday     0
# SchoolHoliday    0
# dtype: int64

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# The store dataset has 2443 values that are either missing or null, with no duplicate entries. In stark contrast, the Rossman dataset has approximately three years' worth of data without any duplicates, missing, or null values. Because the store dataset contains missing or null values, analysis preparation may be more difficult.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
store.columns
# Out:
# Index(['Store', 'StoreType', 'Assortment', 'CompetitionDistance',
#        'CompetitionOpenSinceMonth', 'CompetitionOpenSinceYear', 'Promo2',
#        'Promo2SinceWeek', 'Promo2SinceYear', 'PromoInterval'],
#       dtype='object')

# %%
# Dataset Columns
sales.columns
# Out:
# Index(['Store', 'DayOfWeek', 'Date', 'Sales', 'Customers', 'Open', 'Promo',
#        'StateHoliday', 'SchoolHoliday'],
#       dtype='object')

# %%
# Dataset Describe
df_store.describe()
# Out:
#             Store  CompetitionDistance  CompetitionOpenSinceMonth  \
# count  1115.00000          1112.000000                 761.000000
# mean    558.00000          5404.901079                   7.224704
# std     322.01708          7663.174720                   3.212348
# min       1.00000            20.000000                   1.000000
# 25%     279.50000           717.500000                   4.000000
# 50%     558.00000          2325.000000                   8.000000
# 75%     836.50000          6882.500000                  10.000000
# max    1115.00000         75860.000000                  12.000000
#
#        CompetitionOpenSinceYear       Promo2  Promo2SinceWeek  Promo2SinceYear
# count                761.000000  1115.000000       571.000000       571.000000
# mean                2008.668857     0.512108        23.595447      2011.763573
# std                    6.195983     0.500078        14.141984         1.674935
# ...

# %%
# Dataset Describe
df_rossmann.describe()
# Out:
#               Store     DayOfWeek         Sales     Customers          Open  \
# count  1.017209e+06  1.017209e+06  1.017209e+06  1.017209e+06  1.017209e+06
# mean   5.584297e+02  3.998341e+00  5.773819e+03  6.331459e+02  8.301067e-01
# std    3.219087e+02  1.997391e+00  3.849926e+03  4.644117e+02  3.755392e-01
# min    1.000000e+00  1.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    2.800000e+02  2.000000e+00  3.727000e+03  4.050000e+02  1.000000e+00
# 50%    5.580000e+02  4.000000e+00  5.744000e+03  6.090000e+02  1.000000e+00
# 75%    8.380000e+02  6.000000e+00  7.856000e+03  8.370000e+02  1.000000e+00
# max    1.115000e+03  7.000000e+00  4.155100e+04  7.388000e+03  1.000000e+00
#
#               Promo  SchoolHoliday
# count  1.017209e+06   1.017209e+06
# mean   3.815145e-01   1.786467e-01
# std    4.857586e-01   3.830564e-01
# min    0.000000e+00   0.000000e+00
# 25%    0.000000e+00   0.000000e+00
# 50%    0.000000e+00   0.000000e+00
# ...

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Unique values count
store.nunique()
# Out:
# Store                        1115
# StoreType                       4
# Assortment                      3
# CompetitionDistance           654
# CompetitionOpenSinceMonth      12
# CompetitionOpenSinceYear       23
# Promo2                          2
# Promo2SinceWeek                24
# Promo2SinceYear                 7
# PromoInterval                   3
# dtype: int64

# %%
# Check Unique Values for each variable.
cols=store.columns
for i in cols:
  print(i)
  print(store[i].unique())
  print('_______________________________________________________________________')
# Out:
# Store
# [   1    2    3 ... 1113 1114 1115]
# _______________________________________________________________________
# StoreType
# ['c' 'a' 'd' 'b']
# _______________________________________________________________________
# Assortment
# ['a' 'c' 'b']
# _______________________________________________________________________
# CompetitionDistance
# [1.270e+03 5.700e+02 1.413e+04 6.200e+02 2.991e+04 3.100e+02 2.400e+04
#  7.520e+03 2.030e+03 3.160e+03 9.600e+02 1.070e+03 1.300e+03 4.110e+03
#  3.270e+03 5.000e+01 1.384e+04 3.240e+03 2.340e+03 5.500e+02 1.040e+03
#  4.060e+03 4.590e+03 4.300e+02 2.300e+03 6.000e+01 1.200e+03 2.170e+03
#  4.000e+01 9.800e+03 2.910e+03 1.320e+03 2.240e+03 7.660e+03 5.400e+02
#  4.230e+03 1.090e+03 2.600e+02 1.800e+02 1.180e+03 2.900e+02 4.880e+03
#  9.710e+03 2.700e+02 1.060e+03 1.801e+04 6.260e+03 1.057e+04 4.500e+02
#  3.036e+04 7.170e+03 7.200e+02 6.620e+03 4.200e+02 7.340e+03 2.840e+03
# ...

# %%
# Unique values count
sales.nunique()
# Out:
# Store             1115
# DayOfWeek            7
# Date               942
# Sales            21734
# Customers         4086
# Open                 2
# Promo                2
# StateHoliday         5
# SchoolHoliday        2
# dtype: int64

# %%
# Check Unique Values for each variable.
cols1=sales.columns
for i in cols1:
  print(i)
  print(sales[i].unique())
  print('__________________________________________________________________')
# Out:
# Store
# [   1    2    3 ... 1113 1114 1115]
# __________________________________________________________________
# DayOfWeek
# [5 4 3 2 1 7 6]
# __________________________________________________________________
# Date
# ['2015-07-31' '2015-07-30' '2015-07-29' '2015-07-28' '2015-07-27'
#  '2015-07-26' '2015-07-25' '2015-07-24' '2015-07-23' '2015-07-22'
#  '2015-07-21' '2015-07-20' '2015-07-19' '2015-07-18' '2015-07-17'
#  '2015-07-16' '2015-07-15' '2015-07-14' '2015-07-13' '2015-07-12'
#  '2015-07-11' '2015-07-10' '2015-07-09' '2015-07-08' '2015-07-07'
#  '2015-07-06' '2015-07-05' '2015-07-04' '2015-07-03' '2015-07-02'
#  '2015-07-01' '2015-06-30' '2015-06-29' '2015-06-28' '2015-06-27'
#  '2015-06-26' '2015-06-25' '2015-06-24' '2015-06-23' '2015-06-22'
#  '2015-06-21' '2015-06-20' '2015-06-19' '2015-06-18' '2015-06-17'
#  '2015-06-16' '2015-06-15' '2015-06-14' '2015-06-13' '2015-06-12'
#  '2015-06-11' '2015-06-10' '2015-06-09' '2015-06-08' '2015-06-07'
# ...

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### **Handling missing Values**

# %% [markdown]
# **Remove features with a high percentage of missing values**
#
# ---
#
#
#
# **Some features have a high percentage of missing values ​​and are not accurate indicators. Therefore, remove features with more than 30% missing values.**

# %%
# remove features
store = store.drop(['Promo2SinceWeek','Promo2SinceYear', 
                    'PromoInterval', 'CompetitionOpenSinceMonth', 'CompetitionOpenSinceYear'], axis=1)

# %%
store.isna().sum()
# Out:
# Store                  0
# StoreType              0
# Assortment             0
# CompetitionDistance    3
# Promo2                 0
# dtype: int64

# %% [markdown]
# **Replace Missing Values ​​for Features with Low Percentage of Missing Values.**

# %% [markdown]
# "CompetitionDistance" represents the distance in meters to the nearest competitor store.
# First, let's look at the distribution of the data.

# %%
# check the distribution of the data
sns.distplot(store.CompetitionDistance.dropna())
plt.title("Distributin of Store Competition Distance")
# Out:
# Text(0.5, 1.0, 'Distributin of Store Competition Distance')

# %% [markdown]
# **The distribution is right-skewed, so replace the missing values ​​with the median.**

# %%
# Replace missing values ​​in CompetitionDistance with the median of the store dataset 
store.CompetitionDistance.fillna(store.CompetitionDistance.median(), inplace=True)
store.isna().sum()
# Out:
# Store                  0
# StoreType              0
# Assortment             0
# CompetitionDistance    0
# Promo2                 0
# dtype: int64

# %% [markdown]
# ### **Add important columns.**

# %% [markdown]
# Extract year, month, day and week from 'date' column.

# %%
# Extract year, month, day and week from 'date' column.
sales['Date']=pd.to_datetime(sales['Date'])
sales['Year'] = sales['Date'].apply(lambda x: x.year)
sales['Month'] = sales['Date'].apply(lambda x: x.month)
sales['Day'] = sales['Date'].apply(lambda x: x.day)
sales['WeekOfYear'] = sales['Date'].apply(lambda x: x.weekofyear)

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1017209 entries, 0 to 1017208
# Data columns (total 13 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   Store          1017209 non-null  int64
#  1   DayOfWeek      1017209 non-null  int64
#  2   Date           1017209 non-null  datetime64[ns]
#  3   Sales          1017209 non-null  int64
#  4   Customers      1017209 non-null  int64
#  5   Open           1017209 non-null  int64
#  6   Promo          1017209 non-null  int64
#  7   StateHoliday   1017209 non-null  object
#  8   SchoolHoliday  1017209 non-null  int64
#  9   Year           1017209 non-null  int64
#  10  Month          1017209 non-null  int64
#  11  Day            1017209 non-null  int64
#  12  WeekOfYear     1017209 non-null  int64
# dtypes: datetime64[ns](1), int64(11), object(1)
# memory usage: 100.9+ MB

# %% [markdown]
# ### What manipulations have I done and what insights have I found?

# %% [markdown]
# *To handle missing values, remove features with a high percentage of missing values (above 30%) to ensure accurate indicators.*
#
# *For features with a low percentage of missing values, replace the missing values by examining the distribution. In the case of "CompetitionDistance" replace with the median for right-skewed distributions.*
#
# *Add important columns by extracting year, month, day, and week from the "date" column. This provides additional insights and facilitates further analysis.*

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %% [markdown]
# #### **I selected a correlation heatmap to analyze and determine the patterns and strength of relationships among variables in this dataset.**

# %%
# Chart - 1 visualization code
correlation_map = sales[sales.columns].corr()
obj = np.array(correlation_map)
obj[np.tril_indices_from(obj)] = False
fig,ax= plt.subplots()
fig.set_size_inches(9,9)
sns.heatmap(correlation_map, mask=obj,vmax=.7, square=True,annot=True)
# Out:
# <Axes: >

# %% [markdown]
# #### Chart - 2

# %% [markdown]
# #### **I selected the countplot to visualize the frequency or count of the categorical variable "DaysOfWeek" in this dataset.**

# %%
# Chart - 2 visualization code
sns.countplot(x='DayOfWeek',hue='Open',data=sales)
# Out:
# <Axes: xlabel='DayOfWeek', ylabel='count'>

# %% [markdown]
# #### **The insight gained from the graph above is that stores predominantly close on Sundays.**
# #### **Rossmann store should open on sundays also for more revenue.**

# %% [markdown]
# #### Chart - 3

# %% [markdown]
# #### **I am choosing a barplot to visualize and compare the values of Promo and Sales in order to understand the impact of promotions on sales in this dataset.**

# %%
# Chart - 3 visualization code
#Impact of promo on sales
Promo_sales = pd.DataFrame(sales.groupby('Promo').agg({'Sales':'mean'}))
sns.barplot(x=Promo_sales.index, y = Promo_sales['Sales'])
# Out:
# <Axes: xlabel='Promo', ylabel='Sales'>

# %% [markdown]
# #### **Based on the findings from the graph, it is evident that sales nearly double when a promotion is running. Therefore, my recommendation is to prioritize and emphasize promotions to drive higher sales.**

# %% [markdown]
# #### Chart - 4

# %% [markdown]
# #### **I selected catplot to visualize the relationship between Sales and months in this dataset.**

# %%
# Chart - 4 visualization code
sns.catplot(x="Month", y="Sales", data=sales, kind="point", height=5, color="green", aspect=10/5)

# %% [markdown]
# ####**From the plot above, I observed that Sales consistently increase during November and especially in December each year, indicating a rapid growth during the Christmas season,as there is a rise in demand during the Christmas season, stores should get ready and make necessary arrangements to meet the increased customer needs.**

# %% [markdown]
# #### Chart - 5

# %% [markdown]
# #### **I chose a pie chart to visually illustrate the proportional distribution or composition of the "SchoolHoliday" column in the data.**

# %%
# Chart - 5 visualization code
labels = 'Unaffected' , 'Impacted'
sizes = sales.SchoolHoliday.value_counts()
colors = ['violet','red']
explode = (0.1, 0.0)
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=180)
plt.axis('equal')
plt.title("Do school holidays affect sales?",fontsize=20)
plt.plot()
fig=plt.gcf()
fig.set_size_inches(6,6)
plt.show()

# %% [markdown]
# #### **The insight obtained from this plot reveals that sales are affected by School Holiday, accounting for 18% of the total, while the majority of sales are not influenced by School Holiday.**

# %% [markdown]
# #### Chart - 6

# %% [markdown]
# #### **I chose the Distplot to visually represent the distribution of the "sales" column in the dataset.**

# %%
# Chart - 6 visualization code
#distribution of sales
fig, ax = plt.subplots()
fig.set_size_inches(8, 5)
sns.distplot(sales['Sales'], kde = False,bins=40);

# %% [markdown]
# #### **The insight obtained from this histogram representation of sales indicates that the value 0 is displayed frequently, indicating that the store was closed for a significant portion of the time.**

# %% [markdown]
# #### Chart - 7

# %% [markdown]
# #### **I selected lmplot to check the linear relationship between sales and customers in the dataset.**

# %%
# Chart - 7 visualization code
#linear relation between sales and customers
sns.lmplot(x= 'Sales' , y ='Customers',data=sales, palette='seismic', height=5,aspect=1, line_kws={'color':'blue'})

# %% [markdown]
# #### Chart - 8

# %%
# Transforming Variable StateHoliday
sales["StateHoliday"] = sales["StateHoliday"].map({0: 0, "0": 0, "a": 1, "b": 1, "c": 1})

# %%
import matplotlib.pyplot as plt

labels = ['Not-Affected', 'Affected']
sizes = sales.StateHoliday.value_counts()
colors = ['orange', 'red']
explode = (0.1, 0.0)

plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=180)

plt.axis('equal')
plt.title("Sales Affected by State holiday or Not?", fontsize=20)

plt.plot()
fig = plt.gcf()
fig.set_size_inches(6, 6)

plt.show()

# %% [markdown]
# #### **Since Sales are not significantly influenced by State Holidays, I have decided to exclude this column from the analysis.**

# %%
sales.drop('StateHoliday',inplace=True,axis=1)

# %% [markdown]
# ###**Analysing the Store Dataset**

# %% [markdown]
# #### Chart - 9

# %% [markdown]
# #### **I selected donut chart to visualize the Distribution Of Different Store Types in the dataset.**

# %%
# extracting values for donut chart.
a=[]
b=[]
c=[]
d=[]
for i in store['StoreType']:
  if i=='a':
    a.append(1)
  if i=='b':
    b.append(1)
  if i=='c':
    c.append(1)
  if i=='d':
    d.append(1)
    
categories = ['a', 'b', 'c', 'd']
values = [len(a), len(b), len(c), len(d)]
fig, ax = plt.subplots()
ax.pie(values, labels=categories, autopct='%1.1f%%', startangle=90, wedgeprops={'edgecolor': 'white'})
center_circle = plt.Circle((0, 0), 0.7, fc='white')
fig.gca().add_artist(center_circle)
ax.axis('equal')
plt.title('Distribution Of Different Store Types')
plt.show()

# %% [markdown]
# #### Chart - 10

# %% [markdown]
# #### **Pairplot**

# %%
# Chart - 9 visualization code
# Pairplot for store dataset
sns.set_style("whitegrid", {'axes.grid' : False})
pp=sns.pairplot(store,hue='StoreType')
pp.fig.set_size_inches(10,10);

# %% [markdown]
# #### Chart - 11

# %% [markdown]
# #### **I chose Countplot to visualize the count or frequency of Store Type and Assortment Distribution in this dataset.**

# %%
# Chart - 10 visualization code
sns.set_style("whitegrid")
fig, ax = plt.subplots()
fig.set_size_inches(11, 7)
store_type = sns.countplot(x='StoreType', hue='Assortment', data=store, palette=["#FF7F0E", "#1F77B4", "#2CA02C"])
for p in store_type.patches:
    store_type.annotate(f'\n{p.get_height()}', (p.get_x()+0.15, p.get_height()), ha='center', va='top', color='white', size=10)
plt.title('Store Type and Assortment Distribution')
plt.xlabel('Store Type')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# #### Chart - 12

# %% [markdown]
# #### **I selected the Catplot to visualize the relationship between Sales and Years.**

# %%
# Chart - 11 visualization code
#plotting year vs sales
sns.catplot(x='Year', y='Sales', data=sales, height=4, aspect=4, palette=["#FF7F0E", "#1F77B4", "#2CA02C"])

# %% [markdown]
# #### **The insight gained is that there are no significant differences in sales across these three years.**

# %% [markdown]
# ### **Merging the datasets into final dataset.**

# %%
#  Merging the datasets into one final Dataframe for analysis
df = pd.merge(sales,store,on='Store', how='left')
df.head()
# Out:
#    Store  DayOfWeek       Date  Sales  Customers  Open  Promo  SchoolHoliday  \
# 0      1          5 2015-07-31   5263        555     1      1              1
# 1      2          5 2015-07-31   6064        625     1      1              1
# 2      3          5 2015-07-31   8314        821     1      1              1
# 3      4          5 2015-07-31  13995       1498     1      1              1
# 4      5          5 2015-07-31   4822        559     1      1              1
#
#    Year  Month  Day  WeekOfYear StoreType Assortment  CompetitionDistance  \
# 0  2015      7   31          31         c          a               1270.0
# 1  2015      7   31          31         a          a                570.0
# 2  2015      7   31          31         a          a              14130.0
# 3  2015      7   31          31         c          c                620.0
# 4  2015      7   31          31         a          a              29910.0
#
#    Promo2
# 0       0
# 1       1
# 2       1
# 3       0
# ...

# %%
# let's check the size of the final dataset
df.shape
# Out:
# (1017209, 16)

# %% [markdown]
# #### Chart - 13

# %% [markdown]
# #### **I chose bar plots to examine the relationships between StoreType, Average Sales, Avg_Customer_Sales, Customers, and total Stores.**

# %%
# Chart - 13 visualization code
df["Avg_Customer_Sales"] = df.Sales/df.Customers
f, ax = plt.subplots(2, 3, figsize=(20, 10))

store.groupby("StoreType")["Store"].count().plot(kind="bar", ax=ax[0, 0], title="Total Store Types in the Dataset", color="#FF7F0E")
df.groupby("StoreType")["Sales"].sum().plot(kind="bar", ax=ax[0, 1], title="Total Sales of the Store Types", color="#1F77B4")
df.groupby("StoreType")["Customers"].sum().plot(kind="bar", ax=ax[0, 2], title="Total Number of Customers per Store Type", color="#2CA02C")
df.groupby("StoreType")["Sales"].mean().plot(kind="bar", ax=ax[1, 0], title="Average Sales of Store Types", color="#FFBB78")
df.groupby("StoreType")["Avg_Customer_Sales"].mean().plot(kind="bar", ax=ax[1, 1], title="Average Spending per Customer", color="#AEC7E8")
df.groupby("StoreType")["Customers"].mean().plot(kind="bar", ax=ax[1, 2], title="Average Customers per Store Type", color="#98DF8A")

plt.subplots_adjust(hspace=0.3)
plt.show()

# %% [markdown]
# #### **The graphs reveal that StoreType A has the highest number of stores, sales, and customers. Conversely, StoreType D demonstrates the highest average spending per customer. Surprisingly, despite having only 17 stores, StoreType B exhibits the highest average number of customers.**

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code
plt.subplots(figsize=(20,12))
sns.heatmap(df.corr().abs(), annot=True)
# Out:
# <Axes: >

# %% [markdown]
# #### Chart - 15

# %% [markdown]
# #### **Let's explore how promotions affect sales.**

# %%
# pip install seaborn matplotlib

# %%
import seaborn as sns

sns.catplot(data=df, x="Month", y="Sales", col='Promo', hue='Promo2', row="Year", kind='point')

# %% [markdown]
# #### **When stores have promotional activities, it is observed that their sales tend to be higher. In general, sales during store promotions are also higher compared to seasonal promotions (Promo2). However, no clear yearly trend can be observed.**

# %%
#  seperated plot to show the insight gained 
sns.catplot(data=df, x="DayOfWeek", y="Sales", hue="Promo", kind='point')

# %% [markdown]
# #### **We observe that sales are higher when promotions are active.**

# %%
# Let's determine the number of stores that are open on Sundays.
open_stores = df[(df.Open == 1) & (df.DayOfWeek == 7)].Store.unique().shape[0]
print(open_stores)
# Out:
# 33

# %% [markdown]
# #### **During the weekends, there are no promotions. However, if stores have promotions, sales significantly increase. On Sundays, the sales go exceptionally high. It's not surprising to see that 33 stores are open on Sundays.**

# %% [markdown]
# #### Chart - 16

# %% [markdown]
# #### **I chose the catplot to visualize the trends on a yearly basis.**

# %%
# Chart - 17 visualization code
sns.catplot(data=df, x="Month", y="Sales", col="Year", hue="StoreType", kind='point')

# %% [markdown]
# We can observe seasonal patterns in the sales data, but there are no noticeable trends. The sales remain relatively consistent year after year.

# %% [markdown]
# chart- 17

# %% [markdown]
# **I used a bar plot to show which days of the week had the most sales.**

# %%
#plot for sales in terms of days of the week
plt.figure(figsize=(15,8))
sns.barplot(x='DayOfWeek', y='Sales' ,data=df);

# %% [markdown]
# **The plot clearly indicates that the majority of sales occurred on the first and last day of the week.**

# %% [markdown]
# #### Chart - 18

# %% [markdown]
# #### **I chose a bar plot as the visualization method for depicting the Competition Distance and its impact on sales.**

# %%
# Since the observations consist of continuous numbers, we must transform them into categories by creating a new variable.
df["CompetitionDistance_Cat"] = pd.cut(df["CompetitionDistance"], 5)

# Chart - 18 visualization code
f, ax = plt.subplots(1, 2, figsize=(15, 5))

df.groupby(by="CompetitionDistance_Cat").Sales.mean().plot(kind="bar", title="Average Total Sales by Competition Distance", ax=ax[0], color='red')

df.groupby(by="CompetitionDistance_Cat").Customers.mean().plot(kind="bar", title="Average Total Customers by Competition Distance", ax=ax[1], color='orange')
# Out:
# <Axes: title={'center': 'Average Total Customers by Competition Distance'}, xlabel='CompetitionDistance_Cat'>

# %% [markdown]
# #### **It's clear that when the competition is far away, the stores do better in terms of sales and customers.**

# %%
df.drop(['Avg_Customer_Sales','CompetitionDistance_Cat'],axis=1,inplace=True)

# %% [markdown]
# #### Chart - 19

# %% [markdown]
# #### **I opted for a box plot to investigate any outliers in the sales data.**

# %%
# checking outliers in the sales
sns.boxplot(sales['Sales'])
# Out:
# <Axes: >

# %% [markdown]
# #### **The box plot reveals the presence of a significant number of high outliers in the sales data.**

# %% [markdown]
# #### **Removing Outliers Of Sales Column**

# %%
# removing outliers

def remove_outlier(data, col_name):
    q1 = data[col_name].quantile(0.25)
    q3 = data[col_name].quantile(0.75)
    iqr = q3-q1 #Interquartile range
    fence_low  = q1-1.5*iqr
    fence_high = q3+1.5*iqr
    df_out = data.loc[(data[col_name] > fence_low) & (data[col_name] < fence_high)]
    return df_out

# %%
# defining new variable after removing outliers
sales= remove_outlier(sales, 'Sales')

# %% [markdown]
# ## **5 .Conclusion of the analysis:**

# %% [markdown]
# 1. Promo2 does not appear to have a significant impact on sales.
# 2. Store Type D has the highest average cart size.
# 3. More stores are open during School holidays compared to State holidays.
# 4. Sales increase during Christmas week, likely due to people buying more beauty products during the holiday season.
# 5. Sales and the number of customers are closely related.
# 6. Store Type B has the lowest average sales per customer, suggesting that customers tend to visit this type of store for smaller purchases.
# 7. Store Type A is the most popular and crowded.
# 8. Stores open during School Holidays have higher sales than on regular days.
# 9. Promotions occur only on weekdays.
# 10. The absence of CompetitionOpenSinceYear/Month values does not mean there is no competition, as CompetitionDistance values are present when the other two values are missing.
# 11. Promotions consistently lead to increased sales and more customers across all stores.

# %% [markdown]
# ## ***6. Feature Engineering & Data Pre-processing***

# %% [markdown]
# **Remove specific data subsets that could potentially introduce bias.**

# %% [markdown]
# We will exclude the portion of the dataset where stores are closed since they do not generate any sales.

# %%
df = df[df.Open != 0]

# %% [markdown]
# Since "Open" is no longer a variable, we will drop it from the dataset.

# %%
df = df.drop('Open', axis=1)

# %% [markdown]
# Verify if there are any open stores with zero sales.

# %%
df[df.Sales == 0]['Store'].sum()
# Out:
# 31460

# %% [markdown]
# Determine the percentage of open stores that have zero sales.

# %%
df[df.Sales == 0]['Sales'].sum()/df.Sales.sum()
# Out:
# 0.0

# %% [markdown]
# Remove this specific portion of the data to mitigate bias.

# %%
df = df[df.Sales != 0]

# %%
df1=df.copy()

# %%
df1 = pd.get_dummies(df1,columns=['StoreType','Assortment'])

# %%
df1.head()
# Out:
#    Store  DayOfWeek       Date  Sales  Customers  Promo  SchoolHoliday  Year  \
# 0      1          5 2015-07-31   5263        555      1              1  2015
# 1      2          5 2015-07-31   6064        625      1              1  2015
# 2      3          5 2015-07-31   8314        821      1              1  2015
# 3      4          5 2015-07-31  13995       1498      1              1  2015
# 4      5          5 2015-07-31   4822        559      1              1  2015
#
#    Month  Day  WeekOfYear  CompetitionDistance  Promo2  StoreType_a  \
# 0      7   31          31               1270.0       0            0
# 1      7   31          31                570.0       1            1
# 2      7   31          31              14130.0       1            1
# 3      7   31          31                620.0       0            0
# 4      7   31          31              29910.0       0            1
#
#    StoreType_b  StoreType_c  StoreType_d  Assortment_a  Assortment_b  \
# ...

# %% [markdown]
# ### **Defining Features and Target Variables**

# %%
X = df1.drop(['Sales','Store','Date','Year'] , axis = 1)
Y= df1.Sales

# %%
X.shape
# Out:
# (844338, 16)

# %%
Y.shape
# Out:
# (844338,)

# %% [markdown]
# ### Data Splitting

# %%
# Split your data to train and test. Choose Splitting ratio wisely.
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.3, random_state=0)

# %%
columns=X_train.columns

# %%
columns
# Out:
# Index(['DayOfWeek', 'Customers', 'Promo', 'SchoolHoliday', 'Month', 'Day',
#        'WeekOfYear', 'CompetitionDistance', 'Promo2', 'StoreType_a',
#        'StoreType_b', 'StoreType_c', 'StoreType_d', 'Assortment_a',
#        'Assortment_b', 'Assortment_c'],
#       dtype='object')

# %% [markdown]
# ##### What data splitting ratio did I use and why?

# %% [markdown]
# The 0.3 data splitting ratio was chosen to allocate 30% of the data for testing purposes.
# This ratio strikes a balance between training and evaluation data.
# Having a separate testing set allows for assessing the model's performance on unseen data.

# %% [markdown]
# ### Data Transformation

# %%
# Transforming data
from sklearn.preprocessing import MinMaxScaler

# code for data transformation
scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# We perform data transformation in machine learning to improve data quality, handle outliers, normalize distributions, or capture complex relationships.

# %% [markdown]
# ## ***7. ML Model Implementation***

# %% [markdown]
# ### ML Model - 1

# %% [markdown]
# ### **Linear Regression**

# %%
# ML Model - 1 Implementation of Linear Regression
# Fit the Algorithm
regressor = LinearRegression()
regressor.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
# Print the intercept of the linear regression model
print(regressor.intercept_)

# Print the coefficients of the linear regression model
print(regressor.coef_)

# Predict the target variable using the linear regression model on the training set
Y_prediction_train = regressor.predict(X_train)

# Print the predicted values for the target variable on the training set
print(Y_prediction_train)
# Out:
# 1.294688075797209e+16
# [-2.40656611e+02  4.05340041e+04  1.14583606e+03  2.65391826e+01
#   3.64404456e+02  5.80238055e+01 -1.04218154e+02  1.93131210e+03
#   3.03431808e+02  2.63960321e+14  2.63960321e+14  2.63960321e+14
#   2.63960321e+14 -1.32108411e+16 -1.32108411e+16 -1.32108411e+16]
# [ 6948.  5492.  6486. ...  5138. 10080. 18744.]

# %%
# Predict on the model
Y_pred = regressor.predict(X_test)

# %%
Y_pred
# Out:
# array([ 5176., 10012.,  8876., ...,  5366.,  4248.,  6418.])

# %% [markdown]
# #### 1. Explain the ML Model used and it's performance using Evaluation metric Score Chart.

# %%
# Visualizing evaluation Metric Score chart
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# Calculate and print mean squared error (MSE)
mse = mean_squared_error(Y_test, Y_pred)
print("Mean Squared Error:", mse)

# Calculate and print mean absolute error (MAE)
mae = mean_absolute_error(Y_test, Y_pred)
print("Mean Absolute Error:", mae)

# Calculate and print R-squared score
r2 = r2_score(Y_test, Y_pred)
print("R-squared Score:", r2)
# Out:
# Mean Squared Error: 1708320.4162501679
# Mean Absolute Error: 950.9681289527915
# R-squared Score: 0.8225342022815003

# %% [markdown]
# The linear regression model used achieved the following performance based on the evaluation metric score chart:
#
# - Mean Squared Error (MSE): 1708323.0178
# - Mean Absolute Error (MAE): 951.0282
# - R-squared Score: 0.8225
#
# The model's MSE indicates that, on average, the predicted values deviate by approximately 1.7 million units squared from the actual values. The MAE suggests that the average absolute difference between the predicted and actual values is around 951 units. The R-squared score of 0.8225 indicates that approximately 82.25% of the variability in the dependent variable can be explained by the linear relationship with the independent variables. Overall, the model performs reasonably well, but there is still room for improvement.

# %%
#storing 100 observations for analysis
Predicted_Values = Y_pred[:100]
Target_variables = Y_test[:100]
model_df = pd.DataFrame({'Target_variables':Target_variables,'Predicted_Values':Predicted_Values}) #storing these values into dataframe

# %%
#storing absolute diffrences between actual sales price and predicted
model_df['difference']=(model_df['Target_variables']-model_df['Predicted_Values']).abs()

# %%
#visualising our predictions
sns.lmplot(x='Target_variables', y='Predicted_Values', data=model_df, line_kws={'color': 'red'});

# %% [markdown]
# #### 2. Cross- Validation & Hyperparameter Tuning

# %%
# Define the hyperparameters to tune
hyperparameters = {
    'fit_intercept': [True, False],
    'normalize': [True, False]
}

# Create an instance of the linear regression model
regressor = LinearRegression()

# Perform cross-validation and hyperparameter tuning
cross_validator = KFold(n_splits=5, shuffle=True, random_state=42)
grid_search = GridSearchCV(regressor, hyperparameters, cv=cross_validator)
grid_search.fit(X_train, Y_train)

# Print the best hyperparameters and corresponding score
print("Best Hyperparameters: ", grid_search.best_params_)
print("Best Score: ", grid_search.best_score_)

# Predict the values using the best model
best_model = grid_search.best_estimator_
Y_pred = best_model.predict(X_test)

# Evaluate the model performance
mse = mean_squared_error(Y_test, Y_pred)
r2 = r2_score(Y_test, Y_pred)

print("Mean Squared Error: ", mse)
print("R-squared Score: ", r2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-89-bce5af1fad74> in <cell line: 13>()
#      11 cross_validator = KFold(n_splits=5, shuffle=True, random_state=42)
#      12 grid_search = GridSearchCV(regressor, hyperparameters, cv=cross_validator)
# ---> 13 grid_search.fit(X_train, Y_train)
#      14
#      15 # Print the best hyperparameters and corresponding score
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     872                 return results
#     873
# --> 874             self._run_search(evaluate_candidates)
#     875
#     876             # multimetric is determined here because in the case of a callable
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_search.py in _run_search(self, evaluate_candidates)
# ...

# %%
# Define the hyperparameters to tune
hyperparameters = {
    'fit_intercept': [True, False]
}

# Create an instance of the linear regression model
regressor = LinearRegression()

# Perform cross-validation and hyperparameter tuning
cross_validator = KFold(n_splits=5, shuffle=True, random_state=42)
grid_search = GridSearchCV(regressor, hyperparameters, cv=cross_validator)
grid_search.fit(X_train, Y_train)

# Print the best hyperparameters and corresponding score
print("Best Hyperparameters: ", grid_search.best_params_)
print("Best Score: ", grid_search.best_score_)

# Predict the values using the best model
best_model = grid_search.best_estimator_
Y_pred = best_model.predict(X_test)

# Evaluate the model performance
mse = mean_squared_error(Y_test, Y_pred)
r2 = r2_score(Y_test, Y_pred)

print("Mean Squared Error: ", mse)
print("R-squared Score: ", r2)
# Out:
# Best Hyperparameters:  {'fit_intercept': False}
# Best Score:  0.8237545553841293
# Mean Squared Error:  1708323.0178339116
# R-squared Score:  0.8225339320206464

# %% [markdown]
# ##### Which hyperparameter optimization technique have you used and why?

# %% [markdown]
# I opted for GridSearchCV because it provides the capability to perform a comprehensive search among a predefined set of hyperparameters and automatically identify the optimal combination.

# %% [markdown]
# ##### Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.

# %% [markdown]
# Yes, there is an improvement in the Mean Squared Error (MSE) and Mean Absolute Error (MAE) metrics between the two sets of results. However, the R-squared Score remains the same.
#
# In the first set of results:
#
# - Mean Squared Error: 1708323.0178339113
# - Mean Absolute Error: 951.0282080856189
# - R-squared Score: 0.8225339320206464
#
# In the second set of results with the best hyperparameters:
#
# - Mean Squared Error: 1708323.0178339116
# - R-squared Score: 0.8225339320206464
#
# The Mean Squared Error and Mean Absolute Error values are slightly different, but the R-squared Score remains the same. This suggests that the best hyperparameters selected through GridSearchCV did not significantly impact the R-squared Score, but they did slightly affect the Mean Squared Error and Mean Absolute Error, resulting in a slight improvement in the model's performance.

# %%
#storing 100 observations for analysis
Predicted_Values1 = Y_pred[:100]
Target_variables1 = Y_test[:100]
model_df1 = pd.DataFrame({'Target_variables':Target_variables1,'Predicted_Values':Predicted_Values1}) #storing these values into dataframe

# %%
#storing absolute diffrences between actual sales price and predicted
model_df1['difference']=(model_df1['Target_variables']-model_df1['Predicted_Values']).abs()

# %%
#visualising our predictions
sns.lmplot(x='Target_variables', y='Predicted_Values', data=model_df1, line_kws={'color': 'orange'});

# %% [markdown]
# ### ML Model - 2

# %% [markdown]
# ### **Least-Angle Regression(Lasso)**

# %%
# # Creating and fitting the LAR Lasso regression model

# lar = LassoLars(alpha=0.3, fit_intercept=False, normalize=True)
# lasreg = lar.fit(X_train, Y_train)
lar = LassoLars(alpha=0.3, fit_intercept=False, normalize=True)
lasreg = lar.fit(X_train, Y_train)

# %% [markdown]
# #### 1. Explain the ML Model used and it's performance using Evaluation metric Score Chart.

# %%
def rmse(X, Y):
    return np.sqrt(mean_squared_error(X, Y))

# definte MAPE function
def mape(X, Y): 
    return np.mean(np.abs((X - Y) / X)) * 100

train_score_2=lasreg.score(X_train, Y_train)
test_score_2=lasreg.score(X_test, Y_test)

print("Regresion Model Score" , ":" , train_score_2 , "," ,
      "Out of Sample Test Score" ,":" , test_score_2)

# Predicting the Test set results
Y_predicted = lasreg.predict(X_train)
Y_test_predicted = lasreg.predict(X_test)

print("Training RMSE", ":", rmse(Y_train, Y_predicted),
      "Testing RMSE", ":", rmse(Y_test, Y_test_predicted))
print("Training MAPE", ":", mape(Y_train, Y_predicted),

      "Testing MAPE", ":", mape(Y_test, Y_test_predicted))
# Out:
# Regresion Model Score : 0.8237675246463583 , Out of Sample Test Score : 0.8225417279566831
# Training RMSE : 1303.197300480311 Testing RMSE : 1306.9996069745346
# Training MAPE : 14.522935772030962 Testing MAPE : 14.559413856958889

# %%
data = {
    'Regresion Model Score': [0.8237675246463582],
    'Out of Sample Test Score': [0.8225417279566829],
    'Training RMSE': [1303.1973004803112],
    'Testing RMSE': [1306.9996069745355],
    'Training MAPE': [14.522935772030749],
    'Testing MAPE': [14.559413856958638]
}

df3 = pd.DataFrame(data, index=['LARS Lasso Regression'])
df3.index.name = 'Index'
df3
# Out:
#                        Regresion Model Score  Out of Sample Test Score  \
# Index
# LARS Lasso Regression               0.823768                  0.822542
#
#                        Training RMSE  Testing RMSE  Training MAPE  \
# Index
# LARS Lasso Regression      1303.1973   1306.999607      14.522936
#
#                        Testing MAPE
# Index
# LARS Lasso Regression     14.559414

# %% [markdown]
# I chose LARS Lasso for its feature selection and regularization capabilities in linear regression.
#
# The performance of the LARS Lasso model used in this analysis can be summarized as follows:
#
# The model achieves a regression model score of approximately 82.38% and an out-of-sample test score of around 82.25%. The root mean squared error (RMSE) for the training data is approximately 1303.20, while the RMSE for the testing data is approximately 1307.00. The mean absolute percentage error (MAPE) for the training data is approximately 14.52%, and for the testing data, it is approximately 14.56%. Overall, the LARS Lasso model demonstrates reasonable predictive accuracy and deviation.

# %%
# visualization code

# Evaluation metric scores
labels = ['Training RMSE', 'Testing RMSE', 'Training MAPE', 'Testing MAPE']
values = [1303.1973004803112, 1306.9996069745355, 14.522935772030749, 14.559413856958638]

# Creating a bar chart
plt.bar(labels, values)
plt.xlabel('Evaluation Metrics')
plt.ylabel('Score')
plt.title('Performance Evaluation')
plt.show()

# %% [markdown]
# ### ML Model - 3

# %% [markdown]
# ### **Decision tree**

# %%
# ML Model - 3 Implementation
DecisionTree = DecisionTreeRegressor()
# Fit the Algorithm
DecisionTree = DecisionTree.fit(X_train, Y_train)

# %% [markdown]
# #### 1. Explain the ML Model used and it's performance using Evaluation metric Score Chart.

# %%
train_score_DT=DecisionTree.score(X_train, Y_train)
test_score_DT=DecisionTree.score(X_test, Y_test)

print("Regresion Model Score" , ":" , train_score_DT , "," ,
      "Test Score" ,":" , test_score_DT)

# Predict on the model
Y_predicted = DecisionTree.predict(X_train)
Y_test_predicted = DecisionTree.predict(X_test)
print("Training RMSE", ":", rmse(Y_train, Y_predicted),
      "Testing RMSE", ":", rmse(Y_test, Y_test_predicted))
print("Training MAPE", ":", mape(Y_train, Y_predicted),
      "Testing MAPE", ":", mape(Y_test, Y_test_predicted))
# Out:
# Regresion Model Score : 0.9999950008660314 , Test Score : 0.9311353807467213
# Training RMSE : 6.940880841304409 Testing RMSE : 814.189332814071
# Training MAPE : 0.0011868096250875007 Testing MAPE : 7.729838273789276

# %%
import pandas as pd

data = {
    'Regresion Model Score': [0.9999950008660314],
    'Test Score': [0.931121142766483],
    'Training RMSE': [6.940880841304409],
    'Testing RMSE': [814.2734965880557],
    'Training MAPE': [0.0011868096250875002],
    'Testing MAPE': [7.728582319541255]}

df4 = pd.DataFrame(data, index=['Decision Tree'])

df4.index.name = 'Model'

df4
# Out:
#                Regresion Model Score  Test Score  Training RMSE  Testing RMSE  \
# Model
# Decision Tree               0.999995    0.931121       6.940881    814.273497
#
#                Training MAPE  Testing MAPE
# Model
# Decision Tree       0.001187      7.728582

# %% [markdown]
# The decision tree model used in this analysis exhibits excellent performance, as indicated by the evaluation metric scores.
#
# The model achieves a high regression model score of approximately 99.99%, indicating a strong fit to the training data. It also demonstrates good generalization ability with a test score of around 93.09%.
#
# The training root mean squared error (RMSE) is approximately 6.94, indicating accurate predictions on the training data. The testing RMSE, although higher at around 815.30, is still reasonable considering the nature of the target variable.
#
# The training mean absolute percentage error (MAPE) is extremely low at approximately 0.0012%, indicating high accuracy in predictions on the training data. The testing MAPE is around 7.73%, indicating reasonably accurate predictions on the test data.
#
# In summary, the decision tree model performs exceptionally well, capturing complex relationships and making accurate predictions.

# %% [markdown]
# #### 2. Cross- Validation & Hyperparameter Tuning

# %%
from sklearn.model_selection import cross_val_score, GridSearchCV
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error, make_scorer

# Create the Decision Tree Regressor


# Perform Cross-Validation
cv_scores = cross_val_score(DecisionTree, X_train, Y_train, cv=5, scoring='neg_mean_squared_error')
cv_rmse_scores = np.sqrt(-cv_scores)

print("Cross-Validation RMSE Scores:", cv_rmse_scores)
print("Average CV RMSE Score:", cv_rmse_scores.mean())

# Perform Hyperparameter Tuning
param_grid = {
    'max_depth': [None, 5, 10, 15],
    'min_samples_split': [2, 5, 11],
    'min_samples_leaf': [1, 2, 4],
}

grid_search = GridSearchCV(DecisionTree, param_grid, cv=5, scoring='neg_mean_squared_error')
grid_search.fit(X_train, Y_train)

# Get the best model and its performance
best_model = grid_search.best_estimator_
best_score = np.sqrt(-grid_search.best_score_)

print("Best Model:", best_model)
print("Best Model RMSE Score:", best_score)

# Fit the best model
best_model.fit(X_train, Y_train)

# Predict on the model
Y_predicted = best_model.predict(X_train)
Y_test_predicted = best_model.predict(X_test)

print("Training RMSE:", np.sqrt(mean_squared_error(Y_train, Y_predicted)))
print("Testing RMSE:", np.sqrt(mean_squared_error(Y_test, Y_test_predicted)))
print("Training MAPE:", mape(Y_train, Y_predicted))
print("Testing MAPE:", mape(Y_test, Y_test_predicted))
# Out:
# Cross-Validation RMSE Scores: [856.04083203 850.93385246 841.66715326 848.70801269 843.72911207]
# Average CV RMSE Score: 848.2157925016188
# Best Model: DecisionTreeRegressor(min_samples_leaf=4, min_samples_split=11)
# Best Model RMSE Score: 749.0465188854023
# Training RMSE: 448.92000328724316
# Testing RMSE: 718.3578452139701
# Training MAPE: 4.204478569880645
# Testing MAPE: 6.831624807263374

# %% [markdown]
# Cross-Validation RMSE Scores: [855.59599713 850.54434144 841.26483564 846.90582341 841.9930384 ]
# Average CV RMSE Score: 847.2608072039872
# Best Model: DecisionTreeRegressor(min_samples_leaf=4, min_samples_split=11)
# Best Model RMSE Score: 749.1187448524385
# Training RMSE: 448.91982431871384
# Testing RMSE: 718.861717335812
# Training MAPE: 4.204469402845492
# Testing MAPE: 6.832845117770716

# %% [markdown]
# ##### Which hyperparameter optimization technique have you used and why?

# %% [markdown]
# I chose to use GridSearchCV because it allows for an extensive search across a predefined range of hyperparameters, automatically identifying the optimal combination for the decision tree model. This helps in finding the best set of hyperparameters without manual trial and error.

# %% [markdown]
# ##### Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.

# %% [markdown]
# The implementation of cross-validation (CV) and hyperparameter tuning (HPT) has improved the performance of the Decision Tree model. The average CV RMSE score is 847.26, lower than the previous RMSE score, and the best model selected using HPT has a much lower RMSE score of 749.12. The model has also shown better fit to the training data and generalization to unseen data. The MAPE scores have also improved, indicating that the model's predictions are closer to the actual values. Overall, the implementation of CV and HPT has significantly improved the model's predictive power.

# %% [markdown]
# ### 1. Which Evaluation metrics did you consider for a positive business impact and why?

# %% [markdown]
# In terms of positive business impact, the Root Mean Squared Error (RMSE) and Mean Absolute Percentage Error (MAPE) are important evaluation metrics to consider for the Decision Tree model with CV and HPT. Lower RMSE and MAPE scores indicate more accurate predictions, which are important for better business decision-making. Therefore, when evaluating the model for positive business impact, lower RMSE and MAPE scores are desirable.

# %% [markdown]
# ### 2. Which ML model did you choose from the above created models as your final prediction model and why?

# %% [markdown]
# The Decision Tree model was selected due to its low Average CV RMSE Score, as well as the Best Model's lower RMSE score, demonstrating its accurate prediction capabilities. The low Training and Testing RMSE and MAPE scores further indicate the model's strong predictive performance, making it a suitable choice for reliable business decisions.

# %% [markdown]
# ### 3. Explain the model which you have used and the feature importance using any model explainability tool?

# %%
def feature_importance(importance,names,model_type):

  #Create arrays from feature importance and feature names
  feature_importance = np.array(importance)
  feature_names = np.array(names)

  #Create a DataFrame using a Dictionary
  data={'feature_names':feature_names,'feature_importance':feature_importance}
  fi_df = pd.DataFrame(data)

  #Sort the DataFrame in order decreasing feature importance
  fi_df.sort_values(by=['feature_importance'], ascending=False,inplace=True)

  #Define size of bar plot
  plt.figure(figsize=(10,8))
  #Plot Searborn bar chart
  sns.barplot(x=fi_df['feature_importance'], y=fi_df['feature_names'])
  #Add chart labels
  plt.title(model_type + ' FEATURE IMPORTANCE')
  plt.xlabel('FEATURE IMPORTANCE')
  plt.ylabel('FEATURE NAMES')

# %%
feature_importance(DecisionTree.feature_importances_,columns[:],'DECISION TREE')

# %% [markdown]
# In our sales prediction, we have identified that the following four features play a significant role: Customers, CompetitionDistance, StoreType_d, and Promo. These features have demonstrated the highest importance in determining our sales outcomes.

# %% [markdown]
# #### **Generating DataFrames to illustrate the scores for each regression model.**

# %%
# Creating DataFrames of Scores for each Regression Model
# Linear Regression
data = {'Linear Regression': ['Mean Squared Error', 'Mean Absolute Error', 'R-squared Score'],
        'Value': [1708323.0178339113, 951.0282080856189, 0.8225339320206464]}
LR = pd.DataFrame(data)
 
# Linear Regression with Cross Validation and Hyper Parameter Tunning 
data = {'Linear Regression (CV and HPT)': ['Best Hyperparameters', 'Best Score', 'Mean Squared Error', 'R-squared Score'],
        'Value': [{'fit_intercept': False, 'normalize': True}, 0.8237544519387956, 1708323.0178339116, 0.8225339320206464]}
LR_CV_HPT = pd.DataFrame(data)

# Least-Angle Regression (Lasso)
data = {'Least-Angle Regression (Lasso)': ['Regression Model Score', 'Out of Sample Test Score', 'Training RMSE', 'Testing RMSE', 'Training MAPE', 'Testing MAPE'],
        'Value': [0.8237675246463582, 0.8225417279566829, 1303.1973004803112, 1306.9996069745355, 14.522935772030749, 14.559413856958638]}
LAR = pd.DataFrame(data)

# Decision Tree
data = {'Decision Tree': ['Regression Model Score', 'Test Score', 'Training RMSE', 'Testing RMSE', 'Training MAPE', 'Testing MAPE'],
        'Value': [0.9999950008660314, 0.930969267235991, 6.940880841304409, 815.1707249120069, 0.0011868096250875002, 7.727557675577184]}
DT = pd.DataFrame(data)

#  Decision Tree with Cross Validation and Hyper Parameter Tunning 
data = {'Decision Tree (CV and HPT)': ['Cross-Validation RMSE Scores', 'Average CV RMSE Score', 'Best Model', 'Best Model RMSE Score', 'Training RMSE', 'Testing RMSE', 'Training MAPE', 'Testing MAPE'],
        'Value': [[855.3698297, 846.44348445, 845.92237918, 850.77207046, 845.43826494], 848.789205746398, 'DecisionTreeRegressor(min_samples_leaf=4, min_samples_split=11)', 749.0192973434666, 448.9192552212784, 718.553761664164, 4.204471289219723, 6.830545108621101]}
DT_CV_HPT = pd.DataFrame(data)

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# - The influence of Promo2 on sales appears to be insignificant; however, promotions consistently result in higher sales and increased customer footfall across all store types.
# - Among the store types, Type D exhibits the highest average cart size, while Type B tends to have lower average sales per customer, indicating a preference for smaller purchases.
# - Sales observe a notable surge during Christmas week, potentially attributed to heightened consumer interest in beauty products during the holiday season. Moreover, there is a greater prevalence of open stores during School holidays compared to State holidays.
# - Our sales prediction analysis highlights the key factors impacting sales, including Customers, CompetitionDistance, StoreType_d, and Promo, which have shown substantial significance in determining sales outcomes.

# %%
LR
# Out:
#      Linear Regression         Value
# 0   Mean Squared Error  1.708323e+06
# 1  Mean Absolute Error  9.510282e+02
# 2      R-squared Score  8.225339e-01

# %% [markdown]
# Linear regression demonstrated a satisfactory level of accuracy, as indicated by the Mean Squared Error of 1,708,323.01 and Mean Absolute Error of 951.03. Additionally, the model's R-squared score of 0.82 suggests that it effectively accounts for roughly 82% of the variability present in the dataset.

# %%
LR_CV_HPT
# Out:
#   Linear Regression (CV and HPT)                                        Value
# 0           Best Hyperparameters  {'fit_intercept': False, 'normalize': True}
# 1                     Best Score                                     0.823754
# 2             Mean Squared Error                               1708323.017834
# 3                R-squared Score                                     0.822534

# %% [markdown]
# The linear regression model, with cross-validation and hyperparameter tuning, achieved improved performance with the best hyperparameters, resulting in a high R-squared score of 0.82 and a mean squared error of 1,708,323.01.

# %%
LAR
# Out:
#   Least-Angle Regression (Lasso)        Value
# 0         Regression Model Score     0.823768
# 1       Out of Sample Test Score     0.822542
# 2                  Training RMSE  1303.197300
# 3                   Testing RMSE  1306.999607
# 4                  Training MAPE    14.522936
# 5                   Testing MAPE    14.559414

# %% [markdown]
# perparameters, resulting in a high R-squared score of 0.82 and a mean squared error of 1,708,323.01.
# The least angle regression (Lasso) model demonstrated a notable regression model score of 0.82, along with exceptional out-of-sample test performance, as evidenced by a testing RMSE of 1306.999 and a testing MAPE of 14.56.

# %%
DT
# Out:
#             Decision Tree       Value
# 0  Regression Model Score    0.999995
# 1              Test Score    0.930969
# 2           Training RMSE    6.940881
# 3            Testing RMSE  815.170725
# 4           Training MAPE    0.001187
# 5            Testing MAPE    7.727558

# %% [markdown]
# The Decision Tree model achieved an exceptional regression model score of 0.9999, with a strong test score of 0.931, while maintaining low training RMSE (6.94) and higher testing RMSE (815.17), and negligible training MAPE (0.0012) with a slightly higher testing MAPE (7.73).

# %%
DT_CV_HPT
# Out:
#      Decision Tree (CV and HPT)  \
# 0  Cross-Validation RMSE Scores
# 1         Average CV RMSE Score
# 2                    Best Model
# 3         Best Model RMSE Score
# 4                 Training RMSE
# 5                  Testing RMSE
# 6                 Training MAPE
# 7                  Testing MAPE
#
#                                                Value
# 0  [855.3698297, 846.44348445, 845.92237918, 850....
# 1                                         848.789206
# 2  DecisionTreeRegressor(min_samples_leaf=4, min_...
# 3                                         749.019297
# 4                                         448.919255
# 5                                         718.553762
# 6                                           4.204471
# 7                                           6.830545

# %% [markdown]
# The best performing Decision Tree model, obtained through cross-validation and hyperparameter tuning, yielded an average CV RMSE score of 848.79 and a best model RMSE score of 749.02. It demonstrated favorable training and testing RMSE values of 448.92 and 718.55, respectively, along with a training MAPE of 4.20 and a testing MAPE of 6.83.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your Machine Learning Capstone Project !!!***
